# %% [markdown]
# ## 套件

# %%
import pandas as pd
import statsmodels.api as sm

# %%
# price_data = pd.read_csv('../data/stock_100_price.txt',  encoding='cp950')
# earn_data = pd.read_csv('../data/stock_100_earn.txt',  encoding='cp950')
# institution_data = pd.read_csv('../data/stock_100_institution.txt',  encoding='cp950')
# bs_data = pd.read_csv('../data/stock_100_bs.txt',  encoding='cp950')

price_data = pd.read_csv('../data/stock_price.txt',  encoding='cp950')
earn_data = pd.read_csv('../data/stock_earn.txt',  encoding='cp950')
institution_data = pd.read_csv('../data/stock_institution.txt',  encoding='cp950')
bs_data = pd.read_csv('../data/stock_bs.txt',  encoding='cp950')
# Out:
# /Users/gy/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# 查看前五筆資料
price_data.head()
# Out:
#    證券代碼           簡稱 TSE新產業_名稱 TEJ產業_名稱       年月日  收盤價(元)  成交量(千股)  成交值(千元)  \
# 0  1101  台泥             水泥工業     水泥製造    20170103   35.15     2890   101450
# 1  1102  亞泥             水泥工業     水泥製造    20170103   26.50     1271    33550
# 2  1103  嘉泥             水泥工業     水泥製造    20170103    8.71      278     2411
# 3  1104  環泥             水泥工業     水泥製造    20170103   24.60      150     3705
# 4  1108  幸福             水泥工業     水泥製造    20170103    9.15       20      182
#
#      報酬率％    週轉率％  市值(百萬元)    股價淨值比-TSE 股價淨值比-TEJ
# 0  0.0000  0.0783   129779       1.2300      1.23
# 1  0.5693  0.0378    89078       0.7300      0.73
# 2 -0.2291  0.0359     6748       0.4000      0.48
# 3 -0.2028  0.0236    15610       0.9700      0.97
# 4  0.3289  0.0049     3703       0.7800      0.78

# %%
# 查看後五筆資料
price_data.tail()
# Out:
#          證券代碼           簡稱 TSE新產業_名稱 TEJ產業_名稱       年月日  收盤價(元)  成交量(千股)  \
# 2414085  9955  佳龍           其他         資源回收    20220225   26.50     6713
# 2414086  9957  燁聯             鋼鐵工業     金屬基本    20220225   13.40     4190
# 2414087  9958   世紀鋼           鋼鐵工業     金屬基本    20220225  108.50     1053
# 2414088  9960   邁達康           貿易百貨     百貨批發    20220225   26.75       21
# 2414089  9962  有益             鋼鐵工業     金屬基本    20220225   17.15     1156
#
#          成交值(千元)    報酬率％    週轉率％  市值(百萬元)    股價淨值比-TSE    股價淨值比-TEJ
# 2414085   185048 -8.7780  6.5043     2735       1.8000       1.7970
# 2414086    55859  2.6820  0.1599    35114            -       2.2914
# 2414087   115025  0.0000  0.4545    25136       3.4100       3.4245
# 2414088      555  0.1873  0.0625      899       1.7800       1.7820
# 2414089    19753  3.3133  1.2813     1547       1.5000       1.5036

# %%
rename_column_maplist = {
    '證券代碼' : "code", 
    '公司': 'code',
    '證券名稱': 'code',
    '公司代碼': 'code',
    
    '簡稱' : 'name', 
    'TSE新產業_名稱' : 'new_industry', 
    'TEJ產業_名稱' : 'industry', 
    '年月日'  : "date", 
    '年/月': 'date_year_month',
    '收盤價(元)' : 'close', 
    '成交量(千股)' : 'volume', 
    '成交值(千元)' : 'amount',
    '報酬率％' : 'return', 
    '週轉率％' : "turn_over", 
    '市值(百萬元)' : "size", 
    '股價淨值比-TSE': "PB_TSE", 
    '股價淨值比-TEJ' : 'PB_TEJ',
    
    ### earn
    'ROA－綜合損益': 'ROA',
    '營收成長率': 'YOY',
    '總資產成長率': "TAR",
    
    ### in          
    '外資週轉率%' : 'foreign_turnover_rate',
    '投信週轉率%' : 'trust_turnover_rate',
    '自營商週轉率%' : 'broker_turnover_rate',
    
    ## bs
    '券資比': 'short_margin_ratio',
    '融資餘額(張)' : 'margin_balance',
    '融券餘額(張)' : 'short_balance',
}

# %%
print('欄位改名前：', price_data.columns)
price_data.rename(columns=rename_column_maplist, inplace=True)
print('欄位改名後：', price_data.columns)
# Out:
# 欄位改名前： Index(['證券代碼', '簡稱', 'TSE新產業_名稱', 'TEJ產業_名稱', '年月日', '收盤價(元)', '成交量(千股)',
#        '成交值(千元)', '報酬率％', '週轉率％', '市值(百萬元)', '股價淨值比-TSE', '股價淨值比-TEJ'],
#       dtype='object')
# 欄位改名後： Index(['code', 'name', 'new_industry', 'industry', 'date', 'close', 'volume',
#        'amount', 'return', 'turn_over', 'size', 'PB_TSE', 'PB_TEJ'],
#       dtype='object')

# %%
# https://s61160230.pixnet.net/blog/post/218812467

print('欄位改名前：', earn_data.columns)
earn_data.rename(columns=rename_column_maplist, inplace=True)
print('欄位改名後：', earn_data.columns)
# Out:
# 欄位改名前： Index(['公司', '簡稱', '年/月', '營收成長率', '總資產成長率'], dtype='object')
# 欄位改名後： Index(['code', 'name', 'date_year_month', 'YOY', 'TAR'], dtype='object')

# %%
print('欄位改名前：', institution_data.columns)
institution_data.rename(columns=rename_column_maplist, inplace=True)
print('欄位改名後：', institution_data.columns)
# Out:
# 欄位改名前： Index(['證券名稱', '簡稱', '年月日', '外資週轉率%', '投信週轉率%', '自營商週轉率%'], dtype='object')
# 欄位改名後： Index(['code', 'name', 'date', 'foreign_turnover_rate', 'trust_turnover_rate',
#        'broker_turnover_rate'],
#       dtype='object')

# %%
print('欄位改名前：', bs_data.columns)
bs_data.rename(columns=rename_column_maplist, inplace=True)
print('欄位改名後：', bs_data.columns)
# Out:
# 欄位改名前： Index(['公司代碼', '簡稱', '年月日', '券資比'], dtype='object')
# 欄位改名後： Index(['code', 'name', 'date', 'short_margin_ratio'], dtype='object')

# %% [markdown]
# # 大表

# %%
price_data['code'] = price_data['code'].apply(lambda x: str(x).strip())
institution_data['code'] = institution_data['code'].apply(lambda x: str(x).strip())
bs_data['code'] = bs_data['code'].apply(lambda x: str(x).strip())
earn_data['code'] = earn_data['code'].apply(lambda x: str(x).strip())


price_data['name'] = price_data['name'].apply(lambda x: str(x).strip())
institution_data['name'] = institution_data['name'].apply(lambda x: str(x).strip())
bs_data['name'] = bs_data['name'].apply(lambda x: str(x).strip())
earn_data['name'] = earn_data['name'].apply(lambda x: str(x).strip())

price_data['new_industry'] = price_data['new_industry'].apply(lambda x: str(x).strip())
price_data['industry'] = price_data['industry'].apply(lambda x: str(x).strip())

# %%
merge_data = price_data.merge(institution_data, on=['code', 'name', 'date'])\
.merge(bs_data, on=['code', 'name', 'date'])
merge_data['date_year_month']= merge_data['date'].apply(lambda the_date: int(str(the_date)[:6]))

merge_data['code'] = merge_data['code'].apply(lambda x: str(x).strip())
earn_data['code'] = earn_data['code'].apply(lambda x: str(x).strip())

all_data = merge_data.merge(
    earn_data, on=['code', 'name', 'date_year_month'], how='outer').sort_values(by='date_year_month')

# %% [markdown]
# # 迴圈測試

# %%
from tqdm import tqdm

code_list = all_data['code'].drop_duplicates().values

# %%
base_x_variable_columns = [
        'return', 
        'size', 
        'turn_over', 
        'PB_TSE',
]

ifrs_x_variable_columns = [
        'return', 
        'size', 
        'turn_over', 
        'PB_TSE',
    
        'YOY', 
        'TAR',
]


all_x_variable_columns = [
        'return', 
        'size', 
        'turn_over', 
        'PB_TSE',
    
        'YOY', 
        'TAR',    
    
        'margin_short_ratio', 
        'intitution_turnover_rate',
]

# %%
error_list = []
res_list = []
empty_list = []

for code in tqdm(code_list):
    stock_data = all_data.query('code == @code')

    stock_data = stock_data.ffill()
    stock_data['return_t1'] = stock_data['return'].shift(-1)

    stock_data = stock_data.dropna()

    if stock_data.empty:
        empty_list.append(code)
        continue

    try:

        stock_data['PB_TSE'] = stock_data['PB_TSE'].astype(float)
        stock_data['YOY'] = stock_data['YOY'].astype(float)
        stock_data['TAR'] = stock_data['TAR'].astype(float)

        # 資券比
        stock_data['short_margin_ratio'] = stock_data['short_margin_ratio'].astype(
            float)

        def convert(x):
            if x == 0:
                return 0
            else:
                return 1/(x)*10000
        stock_data['margin_short_ratio'] = stock_data['short_margin_ratio'].apply(
            convert)

        # 合計週轉率
        stock_data['intitution_turnover_rate'] = stock_data[[
            'trust_turnover_rate', 'broker_turnover_rate', 'short_margin_ratio']].sum(1)

    except:
        #print("有問題：", code)
        error_list.append(code)
        continue

    stock_info = stock_data[["code", "name",
                             "new_industry", "industry"]].dropna().iloc[-1, :4]
    mean_size = stock_data['size'].mean()

    y = stock_data['return_t1'].values.reshape((-1, 1))
    x = stock_data[base_x_variable_columns]
    model = sm.OLS(y,  sm.add_constant(x,  prepend=False))
    res = model.fit()       # Fit model
    aviable_t = (res.pvalues < 0.1).sum()
    res_list.append({
        'code': code,
        'res': res,
        'name': stock_info['name'],
        'type': 'base',
        'aviable_t': aviable_t,
        'mean_size': mean_size,
        'new_industry': stock_info['new_industry'],
        'industry': stock_info['industry'],
    })

    y = stock_data['return_t1'].values.reshape((-1, 1))
    x = stock_data[ifrs_x_variable_columns]
    model = sm.OLS(y,  sm.add_constant(x,  prepend=False))
    res = model.fit()       # Fit model
    aviable_t = (res.pvalues < 0.1).sum()
    res_list.append({
        'code': code,
        'res': res,
        'name': stock_info['name'],
        'type': 'ifrs',
        'aviable_t': aviable_t,
        'mean_size': mean_size,
        'new_industry': stock_info['new_industry'],
        'industry': stock_info['industry'],
    })

    y = stock_data['return_t1'].values.reshape((-1, 1))
    x = stock_data[all_x_variable_columns]
    model = sm.OLS(y,  sm.add_constant(x,  prepend=False))
    res = model.fit()       # Fit model
    aviable_t = (res.pvalues < 0.1).sum()
    res_list.append({
        'code': code,
        'res': res,
        'name': stock_info['name'],
        'type': 'all',
        'aviable_t': aviable_t,
        'mean_size': mean_size,
        'new_industry': stock_info['new_industry'],
        'industry': stock_info['industry'],
    })
# Out:
#   0%|          | 0/2370 [00:00<?, ?it/s]/Users/gy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# /Users/gy/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:130: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#  23%|██▎       | 541/2370 [00:42<02:29, 12.23it/s]/Users/gy/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# 100%|██████████| 2370/2370 [03:26<00:00, 11.45it/s]

# %%
res_table = pd.DataFrame(res_list)

# %%
base_table = res_table.query('type == "base"').sort_values('aviable_t', ascending=False)
ifrs_table = res_table.query('type == "ifrs"').sort_values('aviable_t', ascending=False)
all_table = res_table.query('type == "all"').sort_values('aviable_t', ascending=False)

# %%
import numpy as np

# %% [markdown]
# # 考慮 基本市場資料

# %%
base_x_variable_columns
# Out:
# ['return', 'size', 'PB_TSE', 'turn_over']

# %%
print('base vaar : ', len(base_x_variable_columns))
base_pivot_table = base_table.pivot_table(index=['new_industry'], aggfunc=np.mean)\
.sort_values(
    'aviable_t', ascending=False
)
base_pivot_table
# Out:
# base vaar :  4
#               aviable_t      mean_size
# new_industry
# 航運業            2.136364   27872.837039
# 化學工業           1.931034    8866.463582
# 光電業            1.882353   16907.847923
# 玻璃陶瓷           1.800000   12308.098089
# 電子零組件          1.793750   13351.800767
# 生技醫療           1.777778    7095.035840
# 鋼鐵工業           1.617647   20077.313109
# 其他電子業          1.600000   35561.141707
# 造紙工業           1.600000   20009.039968
# 文化創意業          1.583333    7399.615180
# 電器電纜           1.583333    9516.813135
# 通信網路業          1.571429   30439.376913
# 水泥工業           1.571429   55719.295329
# 電子通路業          1.566667    9859.611573
# 電機機械           1.523077    9348.391033
# 食品工業           1.500000   28679.741939
# 橡膠工業           1.500000   30217.029618
# 半導體            1.476190  122455.629002
# 其他             1.415584   15998.725910
# 貿易百貨           1.400000   25630.392804
# 電腦及週邊          1.397436   24220.232094
# 建材營造           1.370968    8351.637662
# 紡織纖維           1.324324   14022.338813
# 塑膠工業           1.318182   88746.344821
# 油電燃氣業          1.222222  117323.194356
# 汽車工業           1.217391   22615.346323
# 資訊服務業          1.190476    3712.684730
# 觀光事業           1.142857    6173.820519
# 金融業            1.050000  112759.529782
# 農業科技           1.000000    2436.804140
# 電子商務           0.666667    9335.343949

# %%
target_new_industry = base_pivot_table.query('aviable_t >= 1.6').index.values

target_industry = base_table[base_table['new_industry'].isin(
    target_new_industry)
]
target_industry.pivot_table(
    index=['new_industry', 'industry'], 
    aggfunc=np.mean
)
# Out:
#                        aviable_t      mean_size
# new_industry industry
# 光電業          主機板        3.000000   21151.773885
#              光電/ IO     1.852459   12066.230285
#              家電製品       2.000000     699.314400
#              消費性電子      2.090909   58038.290468
#              電子設備       1.857143    2856.601652
#              電子零組件      1.500000    5214.632763
# 其他電子業        PC系統       1.500000  700490.344917
#              主機板        1.333333    3524.559041
#              光電/ IO     2.125000    3047.882862
#              其他電子       1.250000    7226.730693
#              半導體        1.000000    9620.300716
#              汽車組件       2.000000   11964.557325
#              消費性電子      1.400000    2725.739219
#              石化         0.666667    2071.225318
#              資源回收       4.000000    1559.096338
#              資訊通路       1.666667    7475.359343
#              醫療耗材       3.000000    1742.253981
#              電子設備       1.764706    9935.015930
#              電子零組件      1.000000   51293.517814
# 化學工業         其他化學       2.000000    8581.629335
#              染料及顏料      2.666667    4760.819268
#              樹脂         1.777778    5671.017870
#              清潔劑        1.750000    5958.612161
#              石化         1.000000   17654.721338
#              藥          2.500000   27713.634952
# 玻璃陶瓷         玻璃陶瓷       1.800000   12308.098089
# 生技醫療         光電/ IO     1.000000    1992.294586
#              其他化學       2.500000   10848.117038
#              其他電製品      2.000000    9524.675159
#              生物科技       0.500000    3003.239650
#              藥          1.821429    8706.014832
#              醫療耗材       1.653846    5775.283419
#              醫藥通路       3.500000    2158.557723
# 航運業          機車船製造      1.500000   21574.195164
#              海運         2.111111   41292.371710
#              空運業        2.000000   68050.764729
#              貨運倉儲業      2.333333    6924.572187
# 造紙工業         紙漿         1.000000   13722.246815
#              造紙         1.750000   21580.738256
# 鋼鐵工業         機車船製造      0.000000    3288.726911
#              金屬基本       1.656250   21196.143312
#              金屬製品       2.000000    1063.332803
# 電子零組件        主機板        1.595238   16012.618254
#              光電/ IO     1.750000   22331.328424
#              家電製品       2.000000     740.438694
#              建設         5.000000    2425.441879
#              汽車組件       1.000000   11204.921178
#              消費性電子      1.500000    1836.248162
#              資訊通路       2.000000    3797.128822
#              通訊設備       2.000000    1336.984873
#              金屬製品       2.000000   35419.479299
#              電子設備       1.800000    3429.858780
#              電子零組件      1.845361   13231.939610

# %% [markdown]
# # 考慮 基本市場資料 ＋ 財務

# %%
ifrs_x_variable_columns
# Out:
# ['return', 'size', 'turn_over', 'YOY', 'TAR', 'PB_TSE']

# %%
print('ifrs vaar : ', len(ifrs_x_variable_columns))
ifrs_pivot_table = ifrs_table.pivot_table(index=['new_industry'], aggfunc=np.mean)\
.sort_values(
    'aviable_t', ascending=False
)
ifrs_pivot_table
# Out:
# ifrs vaar :  6
#               aviable_t      mean_size
# new_industry
# 航運業            2.954545   27872.837039
# 造紙工業           2.800000   20009.039968
# 橡膠工業           2.400000   30217.029618
# 電器電纜           2.250000    9516.813135
# 光電業            2.105882   16907.847923
# 化學工業           2.034483    8866.463582
# 水泥工業           2.000000   55719.295329
# 油電燃氣業          2.000000  117323.194356
# 鋼鐵工業           1.941176   20077.313109
# 電子零組件          1.881250   13351.800767
# 生技醫療           1.857143    7095.035840
# 半導體            1.800000  122455.629002
# 其他電子業          1.800000   35561.141707
# 食品工業           1.791667   28679.741939
# 通信網路業          1.761905   30439.376913
# 文化創意業          1.750000    7399.615180
# 貿易百貨           1.720000   25630.392804
# 金融業            1.625000  112759.529782
# 玻璃陶瓷           1.600000   12308.098089
# 電機機械           1.600000    9348.391033
# 建材營造           1.580645    8351.637662
# 觀光事業           1.571429    6173.820519
# 其他             1.558442   15998.725910
# 塑膠工業           1.545455   88746.344821
# 電子通路業          1.500000    9859.611573
# 電腦及週邊          1.500000   24220.232094
# 紡織纖維           1.459459   14022.338813
# 資訊服務業          1.285714    3712.684730
# 汽車工業           1.260870   22615.346323
# 農業科技           1.000000    2436.804140
# 電子商務           0.666667    9335.343949

# %%
target_new_industry = ifrs_pivot_table.query('aviable_t >= 2').index.values

target_industry = ifrs_table[ifrs_table['new_industry'].isin(
    target_new_industry)
]
target_industry.pivot_table(
    index=['new_industry', 'industry'], 
    aggfunc=np.mean
)
# Out:
#                        aviable_t      mean_size
# new_industry industry
# 光電業          主機板        4.000000   21151.773885
#              光電/ IO     2.065574   12066.230285
#              家電製品       3.000000     699.314400
#              消費性電子      2.181818   58038.290468
#              電子設備       2.142857    2856.601652
#              電子零組件      1.750000    5214.632763
# 化學工業         其他化學       2.222222    8581.629335
#              染料及顏料      2.666667    4760.819268
#              樹脂         2.000000    5671.017870
#              清潔劑        1.500000    5958.612161
#              石化         0.500000   17654.721338
#              藥          3.000000   27713.634952
# 橡膠工業         橡膠         2.000000    6549.499207
#              橡膠原料       3.666667   24267.656051
#              輪胎         1.800000   43253.665924
# 水泥工業         水泥製造       2.000000   55719.295329
# 油電燃氣業        公用事業       2.125000    8472.529160
#              輕油製解       1.000000  988128.515924
# 航運業          機車船製造      2.500000   21574.195164
#              海運         2.888889   41292.371710
#              空運業        1.500000   68050.764729
#              貨運倉儲業      3.444444    6924.572187
# 造紙工業         紙漿         4.000000   13722.246815
#              造紙         2.500000   21580.738256
# 電器電纜         家電製品       2.750000    5328.668328
#              電線         2.000000   11610.885539

# %% [markdown]
# # 考慮 基本市場資料 ＋ 財務 + 投資人情緒

# %%
all_x_variable_columns
# Out:
# ['return',
#  'size',
#  'turn_over',
#  'YOY',
#  'TAR',
#  'PB_TSE',
#  'margin_short_ratio',
#  'intitution_turnover_rate']

# %%
print('all vaar : ', len(all_x_variable_columns))
all_pivot_table = all_table.pivot_table(index=['new_industry'], aggfunc=np.mean)\
.sort_values(
    'aviable_t', ascending=False
)
all_pivot_table
# Out:
# all vaar :  8
#               aviable_t      mean_size
# new_industry
# 農業科技           3.000000    2436.804140
# 航運業            2.909091   27872.837039
# 造紙工業           2.800000   20009.039968
# 電器電纜           2.666667    9516.813135
# 橡膠工業           2.600000   30217.029618
# 油電燃氣業          2.444444  117323.194356
# 水泥工業           2.428571   55719.295329
# 文化創意業          2.416667    7399.615180
# 化學工業           2.344828    8866.463582
# 電子商務           2.333333    9335.343949
# 光電業            2.305882   16907.847923
# 生技醫療           2.253968    7095.035840
# 食品工業           2.250000   28679.741939
# 鋼鐵工業           2.235294   20077.313109
# 半導體            2.219048  122455.629002
# 電機機械           2.169231    9348.391033
# 其他電子業          2.166667   35561.141707
# 電子零組件          2.131250   13351.800767
# 通信網路業          2.111111   30439.376913
# 貿易百貨           2.040000   25630.392804
# 金融業            2.000000  112759.529782
# 塑膠工業           2.000000   88746.344821
# 觀光事業           2.000000    6173.820519
# 建材營造           1.935484    8351.637662
# 其他             1.922078   15998.725910
# 紡織纖維           1.918919   14022.338813
# 資訊服務業          1.809524    3712.684730
# 玻璃陶瓷           1.800000   12308.098089
# 電子通路業          1.733333    9859.611573
# 電腦及週邊          1.730769   24220.232094
# 汽車工業           1.478261   22615.346323

# %%
target_new_industry = all_pivot_table.query('aviable_t >= 2.25').index.values

target_industry = all_table[all_table['new_industry'].isin(
    target_new_industry)
]
target_industry.pivot_table(
    index=['new_industry', 'industry'], 
    aggfunc=np.mean
)
# Out:
#                        aviable_t      mean_size
# new_industry industry
# 光電業          主機板        3.000000   21151.773885
#              光電/ IO     2.311475   12066.230285
#              家電製品       4.000000     699.314400
#              消費性電子      2.545455   58038.290468
#              電子設備       1.857143    2856.601652
#              電子零組件      1.750000    5214.632763
# 化學工業         其他化學       2.444444    8581.629335
#              染料及顏料      3.000000    4760.819268
#              樹脂         2.444444    5671.017870
#              清潔劑        1.750000    5958.612161
#              石化         1.000000   17654.721338
#              藥          3.000000   27713.634952
# 文化創意業        其他         2.500000    4096.287022
#              其他電子       2.000000    8700.436306
#              玻璃陶瓷       2.000000     519.289013
#              百貨批發       1.000000    5186.370223
#              軟體服務       2.333333   10671.966959
#              電視廣播       5.000000    2164.910828
# 橡膠工業         橡膠         3.500000    6549.499207
#              橡膠原料       3.333333   24267.656051
#              輪胎         1.800000   43253.665924
# 水泥工業         水泥製造       2.428571   55719.295329
# 油電燃氣業        公用事業       2.625000    8472.529160
#              輕油製解       1.000000  988128.515924
# 生技醫療         光電/ IO     2.000000    1992.294586
#              其他化學       3.500000   10848.117038
#              其他電製品      3.500000    9524.675159
#              生物科技       0.500000    3003.239650
#              藥          2.285714    8706.014832
#              醫療耗材       2.115385    5775.283419
#              醫藥通路       3.000000    2158.557723
# 航運業          機車船製造      2.500000   21574.195164
#              海運         3.111111   41292.371710
#              空運業        1.500000   68050.764729
#              貨運倉儲業      3.111111    6924.572187
# 農業科技         藥          3.000000    2436.804140
# 造紙工業         紙漿         4.000000   13722.246815
#              造紙         2.500000   21580.738256
# 電器電纜         家電製品       2.750000    5328.668328
#              電線         2.625000   11610.885539
# 電子商務         軟體服務       1.000000    1532.440287
#              通訊設備       3.000000   13236.795780
# 食品工業         其他食品       2.777778   10747.124735
#              油脂飼料       2.100000   16130.973806
#              罐頭加工       4.000000    4000.653662
#              飲料乳品       1.000000  106569.823049

# %% [markdown]
# # 如果只看投資人情緒有影響的

# %%
all_table['is_margin_short_ratio_significant'] = all_table['res'].apply(lambda res: res.pvalues['margin_short_ratio'] <= 0.1 )
all_table['is_intitution_turnover_rate_significant'] = all_table['res'].apply(lambda res: res.pvalues['intitution_turnover_rate']  <= 0.1 )

# %%
print('資券顯著：', all_table['is_margin_short_ratio_significant'].sum())
print('法人顯著：', all_table['is_intitution_turnover_rate_significant'].sum())
print('皆顯著：', (
    all_table['is_margin_short_ratio_significant'] & all_table['is_intitution_turnover_rate_significant']
).sum())
# Out:
# 資券顯著： 115
# 法人顯著： 323
# 皆顯著： 38

# %%
all_significant_table = all_table[all_table['is_margin_short_ratio_significant'] & all_table['is_intitution_turnover_rate_significant']]

# %%
print('all var : ', len(all_x_variable_columns))
all_significant_pivot_table = all_significant_table.pivot_table(
    index=['new_industry'], 
    aggfunc=np.mean,
    values=['aviable_t' , 'mean_size'],
)\
.sort_values(
    'aviable_t', ascending=False
)
all_significant_pivot_table
# Out:
# all var :  8
#               aviable_t      mean_size
# new_industry
# 生技醫療           6.000000   13419.731688
# 其他電子業          5.500000    4098.336783
# 食品工業           5.500000    4247.538615
# 電子零組件          5.000000    3954.314490
# 貿易百貨           5.000000     970.808917
# 紡織纖維           4.500000    3870.374292
# 橡膠工業           4.000000    1030.687102
# 油電燃氣業          4.000000    6301.150478
# 半導體            3.750000   13690.471746
# 通信網路業          3.666667    3174.412161
# 電腦及週邊          3.500000    1749.785032
# 電機機械           3.500000    3559.298567
# 光電業            3.500000    1824.883315
# 其他             3.500000    1104.296576
# 文化創意業          3.500000    1342.099920
# 建材營造           3.500000    3303.347532
# 汽車工業           3.000000   14585.692675
# 金融業            3.000000    7300.417197
# 鋼鐵工業           3.000000    1104.082006
# 化學工業           3.000000    3112.496815
# 電子通路業          2.000000     886.872611
# 水泥工業           2.000000  131746.123408

# %%
all_significant_table.pivot_table(
    index=['new_industry', 'industry'], 
    values=['aviable_t' , 'mean_size'],
    aggfunc=np.mean
)
# Out:
#                        aviable_t      mean_size
# new_industry industry
# 光電業          光電/ IO         3.00    2950.452229
#              家電製品           4.00     699.314400
# 其他           平媒電子報          4.00     587.363057
#              資源回收           3.00    1621.230096
# 其他電子業        光電/ IO         5.00    3602.243631
#              資訊通路           6.00    4594.429936
# 化學工業         樹脂             3.00    3112.496815
# 半導體          半導體            3.75   13690.471746
# 建材營造         建設             3.50    3303.347532
# 文化創意業        玻璃陶瓷           2.00     519.289013
#              電視廣播           5.00    2164.910828
# 橡膠工業         輪胎             4.00    1030.687102
# 水泥工業         水泥製造           2.00  131746.123408
# 汽車工業         汽車組件           3.00   14585.692675
# 油電燃氣業        公用事業           4.00    6301.150478
# 生技醫療         醫療耗材           6.00   13419.731688
# 紡織纖維         人纖             4.00    5815.711783
#              染整             5.00    1925.036800
# 貿易百貨         百貨批發           5.00     970.808917
# 通信網路業        通訊設備           4.00    4924.152866
#              電子零組件          3.50    2299.541809
# 金融業          產險業            3.00    7300.417197
# 鋼鐵工業         金屬基本           3.00    1104.082006
# 電子通路業        資訊通路           2.00     886.872611
# 電子零組件        電子零組件          5.00    3954.314490
# 電機機械         儀器設備           3.00    3464.642516
#              機械業            3.50    3486.547373
#              汽車組件           4.00    3799.457006
# 電腦及週邊        主機板            4.00    1829.633758
#              光電/ IO         3.00    1669.936306
# 食品工業         其他食品           5.50    4247.538615

# %%
all_table.pivot_table(
    index=['new_industry', 'industry'], 
    values=['aviable_t' , 'mean_size'],
    aggfunc=np.mean
)
# Out:
#                        aviable_t      mean_size
# new_industry industry
# 光電業          主機板        3.000000   21151.773885
#              光電/ IO     2.311475   12066.230285
#              家電製品       4.000000     699.314400
#              消費性電子      2.545455   58038.290468
#              電子設備       1.857143    2856.601652
# ...                          ...            ...
# 電腦及週邊        電子零組件      1.952381    7384.124518
# 食品工業         其他食品       2.777778   10747.124735
#              油脂飼料       2.100000   16130.973806
#              罐頭加工       4.000000    4000.653662
#              飲料乳品       1.000000  106569.823049
#
# [186 rows x 2 columns]

# %%
all_significant_table
# Out:
#       code                                                res name type  \
# 1532  1236  <statsmodels.regression.linear_model.Regressio...   宏亞  all
# 3068  4736  <statsmodels.regression.linear_model.Regressio...   泰博  all
# 2066  2459  <statsmodels.regression.linear_model.Regressio...   敦吉  all
# 2069  2458  <statsmodels.regression.linear_model.Regressio...   義隆  all
# 2087  2462  <statsmodels.regression.linear_model.Regressio...  良得電  all
# 308   2916  <statsmodels.regression.linear_model.Regressio...   滿心  all
# 2930  5489  <statsmodels.regression.linear_model.Regressio...   彩富  all
# 2042  8450  <statsmodels.regression.linear_model.Regressio...   霹靂  all
# 1445  1410  <statsmodels.regression.linear_model.Regressio...   南染  all
# 3398  3516  <statsmodels.regression.linear_model.Regressio...  亞帝歐  all
# 3488  4555  <statsmodels.regression.linear_model.Regressio...   氣立  all
# 941   6212  <statsmodels.regression.linear_model.Regressio...   理銘  all
# 692   6240  <statsmodels.regression.linear_model.Regressio...   松崗  all
# 3365  3491  <statsmodels.regression.linear_model.Regressio...  昇達科  all
# 521   3226  <statsmodels.regression.linear_model.Regressio...  至寶電  all
# 1886  9918  <statsmodels.regression.linear_model.Regressio...  欣天然  all
# 2756  6109  <statsmodels.regression.linear_model.Regressio...   亞元  all
# 2522  5102  <statsmodels.regression.linear_model.Regressio...   富強  all
# 3611  4401  <statsmodels.regression.linear_model.Regressio...  東隆興  all
# 3119  3577  <statsmodels.regression.linear_model.Regressio...   泓格  all
# 1295  2064  <statsmodels.regression.linear_model.Regressio...   晉椿  all
# 1709  1530  <statsmodels.regression.linear_model.Regressio...   亞崴  all
# 2987  5438  <statsmodels.regression.linear_model.Regressio...   東友  all
# 1856  2832  <statsmodels.regression.linear_model.Regressio...   台產  all
# 392   3299  <statsmodels.regression.linear_model.Regressio...   帛漢  all
# 335   3031  <statsmodels.regression.linear_model.Regressio...   佰鴻  all
# 3512  4722  <statsmodels.regression.linear_model.Regressio...  國精化  all
# 3431  4549  <statsmodels.regression.linear_model.Regressio...   桓達  all
# 3437  4551  <statsmodels.regression.linear_model.Regressio...  智伸科  all
# 2552  5272  <statsmodels.regression.linear_model.Regressio...   笙科  all
# 3614  4205  <statsmodels.regression.linear_model.Regressio...  中華食  all
# 20    6531  <statsmodels.regression.linear_model.Regressio...  愛普*  all
# 194   6485  <statsmodels.regression.linear_model.Regressio...   點序  all
# 2471  2596  <statsmodels.regression.linear_model.Regressio...   綠意  all
# 2030  8435  <statsmodels.regression.linear_model.Regressio...   鉅邁  all
# 1829  9949  <statsmodels.regression.linear_model.Regressio...   琉園  all
# 629   6265  <statsmodels.regression.linear_model.Regressio...  方土昶  all
# 1496  1102  <statsmodels.regression.linear_model.Regressio...   亞泥  all
#
#       aviable_t      mean_size new_industry industry  \
# 1532          8    1681.958599         食品工業     其他食品
# 3068          6   13419.731688         生技醫療     醫療耗材
# 2066          6    4594.429936        其他電子業     資訊通路
# 2069          6   31412.842400          半導體      半導體
# 2087          5    3954.314490        電子零組件    電子零組件
# 308           5     970.808917         貿易百貨     百貨批發
# 2930          5    3602.243631        其他電子業   光電/ IO
# 2042          5    2164.910828        文化創意業     電視廣播
# 1445          5    1925.036800         紡織纖維       染整
# 3398          4     699.314400          光電業     家電製品
# 3488          4    3877.241242         電機機械      機械業
# 941           4    4539.435510         建材營造       建設
# 692           4     587.363057           其他    平媒電子報
# 3365          4    4924.152866        通信網路業     通訊設備
# 521           4    3799.457006         電機機械     汽車組件
# 1886          4    6301.150478        油電燃氣業     公用事業
# 2756          4     736.305600        通信網路業    電子零組件
# 2522          4    1030.687102         橡膠工業       輪胎
# 3611          4    5815.711783         紡織纖維       人纖
# 3119          4    1829.633758        電腦及週邊      主機板
# 1295          3    1104.082006         鋼鐵工業     金屬基本
# 1709          3    3095.853503         電機機械      機械業
# 2987          3    1669.936306        電腦及週邊   光電/ IO
# 1856          3    7300.417197          金融業      產險業
# 392           3    3862.778017        通信網路業    電子零組件
# 335           3    2950.452229          光電業   光電/ IO
# 3512          3    3112.496815         化學工業       樹脂
# 3431          3    3464.642516         電機機械     儀器設備
# 3437          3   14585.692675         汽車工業     汽車組件
# 2552          3    1692.316083          半導體      半導體
# 3614          3    6813.118631         食品工業     其他食品
# 20            3   19472.524682          半導體      半導體
# 194           3    2184.203822          半導體      半導體
# 2471          3    2067.259554         建材營造       建設
# 2030          3    1621.230096           其他     資源回收
# 1829          2     519.289013        文化創意業     玻璃陶瓷
# 629           2     886.872611        電子通路業     資訊通路
# 1496          2  131746.123408         水泥工業     水泥製造
#
#       margin_short_ratio_p_value  intitution_turnover_rate_p_value  \
# 1532                    0.003542                      1.522624e-05
# 3068                    0.050902                      1.776878e-02
# 2066                    0.016495                      3.356200e-03
# 2069                    0.035465                      8.112333e-02
# 2087                    0.016883                      1.993356e-08
# 308                     0.003444                      1.069376e-05
# 2930                    0.027959                      1.582761e-11
# 2042                    0.059227                      7.998280e-05
# 1445                    0.025973                      9.168076e-02
# 3398                    0.084053                      8.794840e-02
# 3488                    0.060101                      1.749761e-03
# 941                     0.037923                      4.632324e-03
# 692                     0.052700                      2.282653e-02
# 3365                    0.052209                      5.349850e-04
# 521                     0.078316                      8.142086e-02
# 1886                    0.018277                      2.392295e-03
# 2756                    0.022797                      7.944493e-02
# 2522                    0.000007                      1.080454e-06
# 3611                    0.050676                      5.983965e-02
# 3119                    0.069598                      1.111497e-02
# 1295                    0.091371                      1.838490e-04
# 1709                    0.004458                      4.220851e-02
# 2987                    0.090861                      3.477552e-03
# 1856                    0.008334                      1.934054e-03
# 392                     0.000910                      3.882114e-02
# 335                     0.025501                      4.812992e-03
# 3512                    0.043669                      2.127164e-04
# 3431                    0.028371                      1.145049e-03
# 3437                    0.005610                      4.836460e-02
# 2552                    0.064933                      7.188590e-02
# 3614                    0.000013                      4.677824e-03
# 20                      0.021717                      7.659960e-02
# 194                     0.065292                      9.573317e-05
# 2471                    0.033324                      8.924689e-04
# 2030                    0.001381                      1.273235e-02
# 1829                    0.006193                      2.719475e-03
# 629                     0.050784                      8.049533e-02
# 1496                    0.003209                      2.000112e-03
#
#       is_margin_short_ratio_significant  \
# 1532                               True
# 3068                               True
# 2066                               True
# 2069                               True
# 2087                               True
# 308                                True
# 2930                               True
# 2042                               True
# 1445                               True
# 3398                               True
# 3488                               True
# 941                                True
# 692                                True
# 3365                               True
# 521                                True
# 1886                               True
# 2756                               True
# 2522                               True
# 3611                               True
# 3119                               True
# 1295                               True
# 1709                               True
# 2987                               True
# 1856                               True
# 392                                True
# 335                                True
# 3512                               True
# 3431                               True
# 3437                               True
# 2552                               True
# 3614                               True
# 20                                 True
# 194                                True
# 2471                               True
# 2030                               True
# 1829                               True
# 629                                True
# 1496                               True
#
#       is_intitution_turnover_rate_significant
# 1532                                     True
# 3068                                     True
# 2066                                     True
# 2069                                     True
# 2087                                     True
# 308                                      True
# 2930                                     True
# 2042                                     True
# 1445                                     True
# 3398                                     True
# 3488                                     True
# 941                                      True
# 692                                      True
# 3365                                     True
# 521                                      True
# 1886                                     True
# 2756                                     True
# 2522                                     True
# 3611                                     True
# 3119                                     True
# 1295                                     True
# 1709                                     True
# 2987                                     True
# 1856                                     True
# 392                                      True
# 335                                      True
# 3512                                     True
# 3431                                     True
# 3437                                     True
# 2552                                     True
# 3614                                     True
# 20                                       True
# 194                                      True
# 2471                                     True
# 2030                                     True
# 1829                                     True
# 629                                      True
# 1496                                     True

# %% [markdown]
# # 有興趣的投資人指標

# %%
expect_col = ['margin_short_ratio', 'intitution_turnover_rate']
aviable_t_list = []
for res in res_list:
    aviable_t = (res['res'].pvalues[expect_col] < 0.1).sum()
    if aviable_t > 0:
        code = res['code']
        stock_data = all_data.query('code == @code')[["code","name","new_industry","industry"]].dropna()
        stock_info = stock_data.iloc[-1, :4]
        #print(" | ".join(stock_data.iloc[-1, :4].values), aviable_t)
        aviable_t_list.append({
            'code': code,
            'name': stock_info['name'],
            'new_industry': stock_info['new_industry'],
            'industry': stock_info['industry'],
            'aviable_t': aviable_t
        })
aviable_t_table = pd.DataFrame(aviable_t_list)

# %%
aviable_t_table.pivot_table(index=['new_industry'], aggfunc=sum).sort_values(
    'aviable_t', ascending=False
)

# %%
target_industry = aviable_t_table[aviable_t_table['new_industry'].isin(
    ['電子零組件', '半導體', '電機機械', '建材營造'])
]
target_industry.pivot_table(index=['new_industry', 'industry'], aggfunc=sum)

# %%
price_data

# %% [markdown]
# # 單隻

# %%
code = "2498"

stock_data = all_data.query('code == @code')
stock_data = stock_data.ffill().dropna()
stock_data['return_t1'] = stock_data['return'].shift(-1)
stock_data = stock_data.dropna()

try:
    
    stock_data['PB_TSE'] = stock_data['PB_TSE'].astype(float)
    stock_data['YOY'] = stock_data['YOY'].astype(float)
    stock_data['TAR'] = stock_data['TAR'].astype(float)
        
        
    ## 資券比
    stock_data['short_margin_ratio'] = stock_data['short_margin_ratio'].astype(float)
    def convert(x):
        if x == 0 :
            return 0
        else:
            return 1/(x)*10000
    stock_data['margin_short_ratio'] = stock_data['short_margin_ratio'].apply(convert)

    ## 合計週轉率
    stock_data['intitution_turnover_rate']  = stock_data[['trust_turnover_rate', 'broker_turnover_rate', 'short_margin_ratio']].sum(1)

except:
    print("有問題：", code)
    

y = stock_data['return_t1'].values.reshape((-1, 1))
x = stock_data[[
    'return', 
    'size', 
    'PB_TSE',
#     'ROA',
    'YOY', 
    'TAR',
    'turn_over', 
    'margin_short_ratio', 
    'intitution_turnover_rate',
]]

model = sm.OLS(y,  sm.add_constant(x,  prepend=False))
res = model.fit()       # Fit model
print(res.summary())   # Summarize model

aviable_t = (res.pvalues[:-1] < 0.1).sum()
if aviable_t > 2:
    print(stock_data.iloc[0, :3])
    print(aviable_t)
    print('----------')

# %%
code = "2201"
stock_data = all_data.query('code == @code')
stock_data = stock_data.ffill().dropna()
stock_data['return_t1'] = stock_data['return'].shift(-1)
stock_data = stock_data.dropna()

try:
    
    stock_data['PB_TSE'] = stock_data['PB_TSE'].astype(float)
    stock_data['YOY'] = stock_data['YOY'].astype(float)
    stock_data['TAR'] = stock_data['TAR'].astype(float)
        
        
    ## 資券比
    stock_data['short_margin_ratio'] = stock_data['short_margin_ratio'].astype(float)
    def convert(x):
        if x == 0 :
            return 0
        else:
            return 1/(x)*10000
    stock_data['margin_short_ratio'] = stock_data['short_margin_ratio'].apply(convert)

    ## 合計週轉率
    stock_data['intitution_turnover_rate']  = stock_data[['trust_turnover_rate', 'broker_turnover_rate', 'short_margin_ratio']].sum(1)

except:
    print("有問題：", code)
    

y = stock_data['return_t1'].values.reshape((-1, 1))
x = stock_data[[
    'return', 
    'size', 
    'PB_TSE',
#     'ROA',
    'YOY', 
    'TAR',
    'turn_over', 
    'margin_short_ratio', 
    'intitution_turnover_rate',
]]

model = sm.OLS(y,  sm.add_constant(x,  prepend=False))
res = model.fit()       # Fit model
print(res.summary())   # Summarize model

aviable_t = (res.pvalues[:-1] < 0.1).sum()
if aviable_t > 2:
    print(stock_data.iloc[0, :3])
    print(aviable_t)
    print('----------')

# %%
                            OLS Regression Results                            
==============================================================================
Dep. Variable:                      y   R-squared:                       0.010
Model:                            OLS   Adj. R-squared:                  0.004
Method:                 Least Squares   F-statistic:                     1.598
Date:                Mon, 28 Feb 2022   Prob (F-statistic):              0.121
Time:                        17:15:48   Log-Likelihood:                -2597.6
No. Observations:                1256   AIC:                             5213.
Df Residuals:                    1247   BIC:                             5259.
Df Model:                           8                                         
Covariance Type:            nonrobust                                         
============================================================================================
                               coef    std err          t      P>|t|      [0.025      0.975]
--------------------------------------------------------------------------------------------
return                       0.0018      0.029      0.064      0.949      -0.055       0.059
size                     -1.868e-05   1.58e-05     -1.185      0.236   -4.96e-05    1.23e-05
PB_TSE                       0.4055      0.624      0.650      0.516      -0.818       1.630
YOY                         -0.0113      0.008     -1.345      0.179      -0.028       0.005
TAR                         -0.0008      0.009     -0.096      0.923      -0.018       0.016
turn_over                    0.3170      0.105      3.015      0.003       0.111       0.523
margin_short_ratio       -2.458e-07   1.19e-06     -0.206      0.836   -2.58e-06    2.09e-06
intitution_turnover_rate    -0.0107      0.025     -0.421      0.674      -0.060       0.039
const                        0.2918      0.583      0.501      0.617      -0.852       1.436
==============================================================================
Omnibus:                      252.497   Durbin-Watson:                   2.001
Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2497.824
Skew:                           0.627   Prob(JB):                         0.00
Kurtosis:                       9.794   Cond. No.                     6.91e+05
==============================================================================

# %% [markdown]
# # 讀取資料

# %%
price_data = pd.read_csv('./taiwan-index-price-data.txt', encoding='cp950')

# %%
price_data

# %% [markdown]
# # 資料基本欄位檢查

# %%
price_data.info()

# %%
print(price_data['證券代碼'].drop_duplicates())
print('-----------------------------')
print(price_data['簡稱'].drop_duplicates())

# %% [markdown]
# # 查詢資料

# %%
price_data['年月日'] == 20000104

# %% [markdown]
# ##### 為什麼找不到想要的代碼

# %%
target_data = price_data[price_data['證券代碼'] == 'M1800']
target_data

# %%
price_data['證券代碼'].drop_duplicates().values

# %%
def clearSpace(value):
    return value.strip()

# %%
price_data['證券代碼'] = price_data['證券代碼'].apply(clearSpace)
price_data['簡稱'] = price_data['簡稱'].apply(clearSpace)

# %% [markdown]
# #### 再來找看看

# %%
target_data = price_data[price_data['證券代碼'] == 'M1800']
target_data

# %% [markdown]
# ## index 跑掉了？

# %%
target_data = target_data.reset_index(drop=True)
target_data

# %% [markdown]
# # 新增報酬率欄位

# %%
target_data['收盤價(元)']

# %%
target_data['ret'] = target_data['收盤價(元)'].diff(1)/target_data['收盤價(元)'].shift(1)
target_data

# %%
target_data = target_data.dropna()

# %% [markdown]
# # 基本敘述性統計

# %%
target_data.describe()

# %% [markdown]
# ## 偏態 與 峰態

# %%
from scipy import stats

# %%
## 偏態
skew = stats.skew(target_data['收盤價(元)'])
## 峰態 fisher=False 是 Eviews 作法
kurtosis = stats.kurtosis(target_data['收盤價(元)'], fisher=False)

print('skew      :  {}'.format(skew))
print('kurtosis  :  {}'.format(kurtosis))

# %% [markdown]
# # 相關係數表

# %%
target_data.corr()
