# %% [markdown]
# # 財經新報-明泰5月營收26.87 億元
#
# https://finance.technews.tw/2021/06/02/alpha-3380-202105-financial-report/

# %% [markdown]
# ### 1. 網路請求

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://finance.technews.tw/2021/06/02/alpha-3380-202105-financial-report/'
res = requests.get(url)
soup = BeautifulSoup(res.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="zh-TW">
# <![endif]--><!--[if IE 8]>
# <html class="ie ie8" lang="zh-TW">
# <![endif]--><!--[if !(IE 7) | !(IE 8)  ]><!--><html lang="zh-TW">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <!--<meta name="viewport" content="width=device-width" />-->
# <meta content="5DEC29CE8988D72A1C6791568D17E9F3" name="msvalidate.01"/>
# <meta content="Fb8JUo8FsCKBCR6sNHNW83sKPV3W1YRAbpmeWVK0OqA" name="google-site-verification"/>
# <meta content="10.0.0.254" name="tf"/>
# <meta content="明泰5月營收26.87 億元 | TechNews 科技新報" name="Title"/>
# <meta content="明泰（3380）今（2）日公布 5 月營收，達 26.87 億元，較 4 月成長 25.4%，較去年同期成長 1.4%，累計前 5 月營收為 120.24 億元，年增 23.5%。..." name="Description"/>
# <meta content="436202956432960" property="fb:pages"/>
# <!--FB Author Start-->
# <meta content="https://www.facebook.com/technewsinside/" property="article:author"/>
# <!--FB Author END-->
# <title>明泰5月營收26.87 億元 | TechNews 科技新報</title>
# ...

# %% [markdown]
# ### 取得標題

# %%
title_tag = soup.select_one('.entry-title')
title_tag
# Out:
# <h1 class="entry-title">明泰5月營收26.87 億元</h1>

# %% [markdown]
# ### 作者、日期、分類

# %%
soup.select('.body')
# Out:
# [<span class="body"><a href="https://technews.tw/author/financial-report/" rel="author" title="由 TechNews 財報助手 發表">TechNews 財報助手</a></span>,
#  <span class="body">2021 年 06 月 02 日 10:20 </span>,
#  <span class="body">
#  <a href="https://technews.tw/category/finance/finance-report/" title="更多財報快訊分類文章">財報快訊</a>
#  </span>,
#  <span class="body" id="edlink" style="display:none"> | <a href="/wp-admin/post.php?action=edit&amp;post=750710">edit</a></span>]

# %%
author_tag = soup.select('.body')[0]
datetime_tag = soup.select('.body')[1]
article_type_tag = soup.select('.body')[2]

# %% [markdown]
# ### 內文

# %%
article_content_tag = soup.find('div', attrs={'class': 'indent'})
article_content_tag

ResultSet
# Out:
# <div class="indent">
# <div id="outlineList_top" style="display:none;">
# <div class="outlineListGroup">
# </div>
# </div>
# <br/><br/><div>
# <p>明泰（3380）今（2）日公布 5 月營收，達 26.87 億元，較 4 月成長 25.4%，較去年同期成長 1.4%，累計前 5 月營收為 120.24 億元，年增 23.5%。<br/><span id="more-750710"></span></p><div class="inside_AD" id="inside_AD"><iframe frameborder="0" height="250" id="ab8dceef" name="ab8dceef" scrolling="no" src="//www5.technews.tw/www/delivery/afr.php?zoneid=63&amp;cb=INSERT_RANDOM_NUMBER_HERE" width="970"><a href="//www5.technews.tw/www/delivery/ck.php?n=ae7f5990&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="//www5.technews.tw/www/delivery/avw.php?zoneid=63&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=ae7f5990"/></a></iframe></div>
# </div>
# ...

# %% [markdown]
# # 整理為純文字

# %%
id

# %%
article = {
    'url': res.url,
    'title': title_tag.text,
    'author': author_tag.text,
    'datetime': datetime_tag.text,
    'article_type': article_type_tag.text,
    'article_content': article_content_tag.text
}

# %%
article
# Out:
# {'url': 'https://finance.technews.tw/2021/06/02/alpha-3380-202105-financial-report/',
#  'title': '明泰5月營收26.87 億元',
#  'author': 'TechNews 財報助手',
#  'datetime': '2021 年 06 月 02 日 10:20 ',
#  'article_type': '\n財報快訊\n',
#  'article_content': '\n\n\n\n\n\n明泰（3380）今（2）日公布 5 月營收，達 26.87 億元，較 4 月成長 25.4%，較去年同期成長 1.4%，累計前 5 月營收為 120.24 億元，年增 23.5%。\n\n\n'}

# %% [markdown]
# ### 人生不要留白

# %%
article = {
    'url': res.url,
    'title': title_tag.text.strip(),
    'author': author_tag.text.strip(),
    'datetime': datetime_tag.text.strip(),
    'article_type': article_type_tag.text.strip(),
    'article_content': article_content_tag.text.strip(),
}
article
# Out:
# {'url': 'https://finance.technews.tw/2021/06/02/alpha-3380-202105-financial-report/',
#  'title': '明泰5月營收26.87 億元',
#  'author': 'TechNews 財報助手',
#  'datetime': '2021 年 06 月 02 日 10:20',
#  'article_type': '財報快訊',
#  'article_content': '明泰（3380）今（2）日公布 5 月營收，達 26.87 億元，較 4 月成長 25.4%，較去年同期成長 1.4%，累計前 5 月營收為 120.24 億元，年增 23.5%。'}

# %% [markdown]
# # 打包自訂函數

# %%
def getNewsContent(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'lxml')
    
    title_tag = soup.select_one('.entry-title')
    author_tag = soup.select('.body')[0]
    datetime_tag = soup.select('.body')[1]
    article_type_tag = soup.select('.body')[2]
    
    article_content_tag = soup.find('div', attrs={'class': 'indent'})
    
    article = {
        'url': res.url,
        'title': title_tag.text.strip(),
        'author': author_tag.text.strip(),
        'datetime': datetime_tag.text.strip(),
        'article_type': article_type_tag.text.strip(),
        'article_content': article_content_tag.text.strip(),
    }
    return article

# %% [markdown]
# # 不同的網址

# %%
getNewsContent(
    'https://finance.technews.tw/2021/05/07/topco-5434-202104-financial-report/'
)
# Out:
# {'url': 'https://finance.technews.tw/2021/05/07/topco-5434-202104-financial-report/',
#  'title': '崇越4月營收月增9.7%',
#  'author': 'TechNews 財報助手',
#  'datetime': '2021 年 05 月 07 日 11:10',
#  'article_type': '財報快訊',
#  'article_content': '崇越（5434）公布 4 月合併營收 37.56 億元，較上（3）月成長 9.7%，與去年同期相比為年增 10.1%；累計其今年前 4 月營收為 132.89 億元，較去年同期增加 8.9%。'}
